# %% [markdown]
# <a href="https://colab.research.google.com/github/hanainajmal/DataAnalysisProjects/blob/master/Impact_of_Music_on_Mental_Health_and_Mood.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Impact of Music 🎶 on Mental Health 💟 and Mood![Screenshot 2023-02-05 at 4.37.00 PM.png](data:image/png;base64,...)**

# %% [markdown]
# # Project Background

# %% [markdown]
# **Introduction:**
#
# Music has been a source of comfort and inspiration for humans for centuries. In recent times, it has gained popularity as a form of therapy for mental health issues. The purpose of this study was to assess the impact of music on people's mental health and mood in general.
#
# **Methodology:**
#
# A survey was conducted to gather information from participants about their musical preferences, listening habits, and overall state of mind. The survey was completed by over 700 participants and recorded their responses. Respondents were given 16 genres of music and asked to rank the frequency of listening to each, with options ranging from never to very frequently. They were also asked to rank the intensity of their feelings of anxiety, depression, insomnia, and OCD on a scale of 1 to 10, with 0 being the lowest in intensity and 10 being the highest.

# %% [markdown]
# # Data Cleaning and Processing

# %%
import pandas as pd

# Load the dataset into a pandas DataFrame
df = pd.read_csv("/content/Music-and-Therapy-survey-1.csv")

# Check for missing values
print("Missing values:", df.isnull().sum().sum())

# Remove any rows with missing values
df.dropna(inplace=True)

# Check for duplicate records
print("Duplicate records:", df.duplicated().sum())

# Remove any duplicate records
df.drop_duplicates(inplace=True)
# Out:
# Missing values: 129
# Duplicate records: 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset into a pandas DataFrame
df = pd.read_csv("/content/Music-and-Therapy-survey-1.csv")

# Create a heatmap to visualize missing values
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')

# Show the plot
plt.show()

# %%
df.head()
# Out:
#          Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29  18.0                   Spotify            3.0
# 1  8/27/2022 19:57  63.0                   Pandora            1.5
# 2  8/27/2022 21:28  18.0                   Spotify            4.0
# 3  8/27/2022 21:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# ...

# %%
 

# Check for missing values
print("Missing values:", df.isnull().sum().sum())

# Option 2: Replace the missing values with the mean of the column
df.fillna(df.mean(), inplace=True)

# Check for missing values after handling
print("Missing values after handling:", df.isnull().sum().sum())

# Save the cleaned and processed data to a new file
df.to_csv("music_survey_data_processed.csv", index=False)
# Out:
# Missing values: 129
# Missing values after handling: 21
# <ipython-input-12-cefa399ab102>:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(), inplace=True)

# %%
 # View the dimensions of the dataset
print("Shape:", df.shape)
# Out:
# Shape: (736, 33)

# %%
# View the summary statistics of the dataset
print(df.describe())
# Out:
#               Age  Hours per day           BPM     Anxiety  Depression  \
# count  736.000000     736.000000  7.360000e+02  736.000000  736.000000
# mean    25.206803       3.572758  1.589948e+06    5.837636    4.796196
# std     12.046766       3.028199  3.685622e+07    2.793054    3.028870
# min     10.000000       0.000000  0.000000e+00    0.000000    0.000000
# 25%     18.000000       2.000000  1.050000e+02    4.000000    2.000000
# 50%     21.000000       3.000000  1.280000e+02    6.000000    5.000000
# 75%     28.000000       5.000000  1.630000e+02    8.000000    7.000000
# max     89.000000      24.000000  1.000000e+09   10.000000   10.000000
#
#          Insomnia         OCD
# count  736.000000  736.000000
# mean     3.738451    2.637228
# std      3.088689    2.842017
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      3.000000    2.000000
# 75%      6.000000    5.000000
# max     10.000000   10.000000

# %%
# View the data types of the columns
print(df.dtypes)
# Out:
# Timestamp                        object
# Age                             float64
# Primary streaming service        object
# Hours per day                   float64
# While working                    object
# Instrumentalist                  object
# Composer                         object
# Fav genre                        object
# Exploratory                      object
# Foreign languages                object
# BPM                             float64
# Frequency [Classical]            object
# Frequency [Country]              object
# Frequency [EDM]                  object
# Frequency [Folk]                 object
# Frequency [Gospel]               object
# Frequency [Hip hop]              object
# Frequency [Jazz]                 object
# Frequency [K pop]                object
# Frequency [Latin]                object
# Frequency [Lofi]                 object
# Frequency [Metal]                object
# Frequency [Pop]                  object
# ...

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the survey data into a Pandas dataframe
df = pd.read_csv("/content/Music-and-Therapy-survey-1.csv")

# Check the column names in the dataframe
print(df.columns)
# Out:
# Index(['Timestamp', 'Age', 'Primary streaming service', 'Hours per day',
#        'While working', 'Instrumentalist', 'Composer', 'Fav genre',
#        'Exploratory', 'Foreign languages', 'BPM', 'Frequency [Classical]',
#        'Frequency [Country]', 'Frequency [EDM]', 'Frequency [Folk]',
#        'Frequency [Gospel]', 'Frequency [Hip hop]', 'Frequency [Jazz]',
#        'Frequency [K pop]', 'Frequency [Latin]', 'Frequency [Lofi]',
#        'Frequency [Metal]', 'Frequency [Pop]', 'Frequency [R&B]',
#        'Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]',
#        'Anxiety', 'Depression', 'Insomnia', 'OCD', 'Music effects',
#        'Permissions'],
#       dtype='object')

# %%
# Plot the distribution of age using a histogram
plt.hist(df["Age"], bins=20)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Distribution of Age")
# Out:
# Text(0.5, 1.0, 'Distribution of Age')

# %%
# Plot the frequency of music listening for each genre using a bar graph
sns.countplot(x="Frequency [Classical]", hue="Anxiety", data=df)
plt.xticks(rotation=200)
plt.xlabel("Frequency [Classical]")
plt.ylabel("Frequency")
plt.title("Frequency of Music Listening for each Genre")
# Out:
# Text(0.5, 1.0, 'Frequency of Music Listening for each Genre')

# %%
# Plot the frequency of music listening for each genre using a bar graph
sns.countplot(x="Frequency [Classical]", hue="Age", data=df)
plt.xticks(rotation=20)
plt.xlabel("Frequency [Classical]")
plt.ylabel("Frequency")
plt.title("Frequency of Music Listening for each Genre")
# Out:
# Text(0.5, 1.0, 'Frequency of Music Listening for each Genre')

# %%
# Plot the relationship between anxiety levels and hours per day listening to music
sns.scatterplot(x="Hours per day", y="Anxiety", data=df)
plt.xlabel("Hours per day")
plt.ylabel("Anxiety")
plt.title("Relationship between Hours per day and Anxiety")
# Out:
# Text(0.5, 1.0, 'Relationship between Hours per day and Anxiety')

# %%
# Plot the correlation between the intensity of mental health issues and the frequency of listening to music
sns.jointplot(x=df["Anxiety"], y=df["Frequency [Classical]"], kind="reg")
plt.xlabel("Anxiety")
plt.ylabel("Frequency of listening [Classical]")
plt.title("Correlation between anxiety and frequency of listening to classical music")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-447623d19f6d> in <module>
#       1 # Plot the correlation between the intensity of mental health issues and the frequency of listening to music
# ----> 2 sns.jointplot(x=df["Anxiety"], y=df["Frequency [Classical]"], kind="reg")
#       3 plt.xlabel("Anxiety")
#       4 plt.ylabel("Frequency of listening [Classical]")
#       5 plt.title("Correlation between anxiety and frequency of listening to classical music")
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
# Bin the age data into different age groups
bins = [0, 18, 25, 35, 45, 60, 100]
df["Age group"] = pd.cut(df["Age"], bins, labels=["<18", "18-24", "25-34", "35-44", "45-59", "60+"])

# Plot the frequency of listening for each genre by age group using a violin plot
sns.plot(x=df["Age"], y=df["Frequency [Pop]"])
plt.xlabel("Age group")
plt.ylabel("Frequency of listening [Pop]")
plt.title("Frequency of listening for Pop genre by age group")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-5c3ad2dac122> in <module>
#       4
#       5 # Plot the frequency of listening for each genre by age group using a violin plot
# ----> 6 sns.pieplot(x=df["Age"], y=df["Frequency [Pop]"])
#       7 plt.xlabel("Age group")
#       8 plt.ylabel("Frequency of listening [Pop]")
#
# AttributeError: module 'seaborn' has no attribute 'pieplot'

# %%
# Group the data by the primary streaming service and count the occurrences
grouped = df.groupby("Primary streaming service").size().reset_index(name='counts')

# Plot the data as a pie chart
plt.pie(grouped["counts"], labels=grouped["Primary streaming service"], startangle=90, autopct='%1.1f%%')
plt.axis('equal')  # Make the pie chart a circle
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-ad7186fd9399> in <module>
# ----> 1 genre_colum = [col for col in data.columns if 'Frequency' in col]
#       2 corr = data[genre_colum + ['Anxiety', 'Depression', 'Insomnia', 'OCD']].corr()
#       3 corr
#       4
#
# NameError: name 'data' is not defined
